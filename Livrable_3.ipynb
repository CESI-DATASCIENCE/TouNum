# %% [markdown]
# # Imports

# %%
# !pip install -U scikit-learn scipy matplotlib
# !pip install tqdm

import tensorflow as tf

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import collections
import random
import re
import numpy as np
import os
import time
import json
from glob import glob
from PIL import Image
import pickle
from tqdm import tqdm

import zipfile

# %% [markdown]
# # Loading data

# %%
# Path to the annotation file
annotation_folder = os.path.abspath('.') + "/MS_COCO/annotations/"
annotation_file = annotation_folder + "captions_train2014.json"

print("annotation_folder", annotation_folder)
print("annotation_file", annotation_file)

# Path to the folder containing images to annotate
image_folder = '/MS_COCO/train2014/'
PATH = os.path.abspath('.') + image_folder

print("the path PATH", PATH)
# Out:
# annotation_folder c:\Users\P3mas\Projects\TouNum/MS_COCO/annotations/
# annotation_file c:\Users\P3mas\Projects\TouNum/MS_COCO/annotations/captions_train2014.json
# the path PATH c:\Users\P3mas\Projects\TouNum/MS_COCO/train2014/

# %%
with open(annotation_folder + "/captions_val2014.json", 'r') as f:
    annotations = json.load(f)

with open(annotation_folder + "instances_val2014.json", 'r') as f:
    instances = json.load(f)

# %%
# Reading the annotation file
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# Group all annotations having the same ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
    # mark the beginning and end of each annotation
    caption = f"<start> {val['caption']} <end>"
    # The ID of an image is part of its access path
    image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
    # Add the caption associated with image_path
    image_path_to_caption[image_path].append(caption)

# %%
# Take only the first images
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)
train_image_paths = image_paths[:10000]
print(len(train_image_paths))
# Out:
# 10000

# %% [markdown]
# On affiche un example d'image et de ses annotations

# %%
# List of all annotations
train_captions = []
# List of all image filenames duplicated (as many times as annotations per image)
img_name_vector = []

for image_path in train_image_paths:
    caption_list = image_path_to_caption[image_path]
    # Add caption_list to train_captions
    train_captions.extend(caption_list)
    # Add image_path duplicated len(caption_list) times
    img_name_vector.extend([image_path] * len(caption_list))

# %%
print(len(train_captions), len(img_name_vector))
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# 50017 50017
# <start> A cow grazing on lush green grass in a field. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x428>

# %% [markdown]
# # 2 Pre-treat datas

# %%
# Downloading the pre-trained InceptionV3 model trained on ImageNet for classification
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
# Creating a variable that will be the input of the new image pre-processing model
new_input = image_model.input
# Retrieve the last hidden layer which contains the image in a compact representation
hidden_layer = image_model.layers[-1].output

# Model that computes a dense representation of images using InceptionV3
image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %%
def load_image(image_path):
    """
    The load_image function takes the path of an image as input and returns a tuple
    containing the processed image and its access path.
    The load_image function performs the following steps:
        1. Load the file corresponding to the image_path.
        2. Decode the image in RGB.
        3. Resize the image to size (299, 299).
        4. Normalize the image pixels between -1 and 1.
    """
    # Read the image file
    img = tf.io.read_file(image_path)
    # Decode the image in RGB
    img = tf.image.decode_jpeg(img, channels=3)
    # Resize the image to size (299, 299)
    img = tf.image.resize(img, (299, 299))
    # Normalize the image pixels between -1 and 1
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
from tqdm import tqdm

# Image preprocessing
# Get the image filenames
encode_train = sorted(set(img_name_vector))

# Create an instance of "tf.data.Dataset" from the image filenames
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
# Split the data into batches after applying the preprocessing done by load_image
image_dataset = image_dataset.map(
    load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

# Iterate through the dataset batch by batch to apply InceptionV3 preprocessing
for img, path in tqdm(image_dataset):
    # Preprocess the current batch (of size (16,8,8,2048)) with InceptionV3
    batch_features = image_features_extract_model(img)
    # Resize the batch from size (16,8,8,2048) to size (16,64,2048)
    batch_features = tf.reshape(batch_features,
                                (batch_features.shape[0], -1, batch_features.shape[3]))
    # Loop through the current batch and save the path and the batch using np.save()
    for bf, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        # (image path associated with its new representation, image representation)
        np.save(
            path_of_feature, bf.numpy()
        )
# Out:
#   6%|▌         | 38/625 [00:47<12:13,  1.25s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 16
#      13 # Iterate through the dataset batch by batch to apply InceptionV3 preprocessing
#      14 for img, path in tqdm(image_dataset):
#      15     # Preprocess the current batch (of size (16,8,8,2048)) with InceptionV3
# ---> 16     batch_features = image_features_extract_model(img)
#      17     # Resize the batch from size (16,8,8,2048) to size (16,64,2048)
#      18     batch_features = tf.reshape(batch_features,
#      19                                 (batch_features.shape[0], -1, batch_features.shape[3]))
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\layer.py:909, in Layer.__call__(self, *args, **kwargs)
#     907         outputs = super().__call__(*args, **kwargs)
#     908 else:
# --> 909     outputs = super().__call__(*args, **kwargs)
#     910 # Change the layout for the layer output if needed.
#     911 # This is useful for relayout intermediate tensor in the model
#     912 # to achieve the optimal performance.
#     913 distribution = distribution_lib.distribution()
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\ops\operation.py:52, in Operation.__call__(self, *args, **kwargs)
#      47                 call_fn = self.call
#      48     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      49         call_fn,
#      50         object_name=(f"{self.__class__.__name__}.call()"),
#      51     )
# ---> 52     return call_fn(*args, **kwargs)
#      54 # Plain flow.
#      55 if any_symbolic_tensors(args, kwargs):
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:183, in Functional.call(self, inputs, training, mask)
#     181         if mask is not None:
#     182             backend.set_keras_mask(x, mask)
# --> 183 outputs = self._run_through_graph(
#     184     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     185 )
#     186 return unpack_singleton(outputs)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\ops\function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:643, in operation_fn.<locals>.call(*args, **kwargs)
#     637 if (
#     638     hasattr(operation, "_call_has_training_arg")
#     639     and operation._call_has_training_arg
#     640     and training is not None
#     641 ):
#     642     kwargs["training"] = training
# --> 643 return operation(*args, **kwargs)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\layer.py:909, in Layer.__call__(self, *args, **kwargs)
#     907         outputs = super().__call__(*args, **kwargs)
#     908 else:
# --> 909     outputs = super().__call__(*args, **kwargs)
#     910 # Change the layout for the layer output if needed.
#     911 # This is useful for relayout intermediate tensor in the model
#     912 # to achieve the optimal performance.
#     913 distribution = distribution_lib.distribution()
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\ops\operation.py:52, in Operation.__call__(self, *args, **kwargs)
#      47                 call_fn = self.call
#      48     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      49         call_fn,
#      50         object_name=(f"{self.__class__.__name__}.call()"),
#      51     )
# ---> 52     return call_fn(*args, **kwargs)
#      54 # Plain flow.
#      55 if any_symbolic_tensors(args, kwargs):
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:243, in BaseConv.call(self, inputs)
#     242 def call(self, inputs):
# --> 243     outputs = self.convolution_op(
#     244         inputs,
#     245         self.kernel,
#     246     )
#     247     if self.use_bias:
#     248         if self.data_format == "channels_last":
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:233, in BaseConv.convolution_op(self, inputs, kernel)
#     232 def convolution_op(self, inputs, kernel):
# --> 233     return ops.conv(
#     234         inputs,
#     235         kernel,
#     236         strides=list(self.strides),
#     237         padding=self.padding,
#     238         dilation_rate=self.dilation_rate,
#     239         data_format=self.data_format,
#     240     )
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\ops\nn.py:1306, in conv(inputs, kernel, strides, padding, data_format, dilation_rate)
#    1302 if any_symbolic_tensors((inputs,)):
#    1303     return Conv(strides, padding, data_format, dilation_rate).symbolic_call(
#    1304         inputs, kernel
#    1305     )
# -> 1306 return backend.nn.conv(
#    1307     inputs, kernel, strides, padding, data_format, dilation_rate
#    1308 )
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\nn.py:331, in conv(inputs, kernel, strides, padding, data_format, dilation_rate)
#     329     return _conv_xla()
#     330 else:
# --> 331     return _conv()
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\nn.py:304, in conv.<locals>._conv()
#     302 def _conv():
#     303     tf_data_format = _convert_data_format(data_format, len(inputs.shape))
# --> 304     return tf.nn.convolution(
#     305         inputs,
#     306         kernel,
#     307         strides,
#     308         padding.upper(),
#     309         data_format=tf_data_format,
#     310         dilations=dilation_rate,
#     311     )
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\nn_ops.py:1186, in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1176 @tf_export("nn.convolution", v1=[])
#    1177 @dispatch.add_dispatch_support
#    1178 def convolution_v2(  # pylint: disable=missing-docstring
#    (...)
#    1184     dilations=None,
#    1185     name=None):
# -> 1186   return convolution_internal(
#    1187       input,  # pylint: disable=redefined-builtin
#    1188       filters,
#    1189       strides=strides,
#    1190       padding=padding,
#    1191       data_format=data_format,
#    1192       dilations=dilations,
#    1193       name=name)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\nn_ops.py:1319, in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1316   else:
#    1317     op = conv1d
# -> 1319   return op(
#    1320       input,
#    1321       filters,
#    1322       strides,
#    1323       padding=padding,
#    1324       data_format=data_format,
#    1325       dilations=dilations,
#    1326       name=name)
#    1327 else:
#    1328   if channel_index == 1:
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\nn_ops.py:2793, in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2789 input_rank = input.shape.rank
#    2790 if input_rank is None or input_rank < 5:
#    2791   # We avoid calling squeeze_batch_dims to reduce extra python function
#    2792   # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2793   return gen_nn_ops.conv2d(
#    2794       input,
#    2795       filter=filters,
#    2796       strides=strides,
#    2797       padding=padding,
#    2798       data_format=data_format,
#    2799       dilations=dilations,
#    2800       name=name)
#    2801 return squeeze_batch_dims(
#    2802     input,
#    2803     functools.partial(
#    (...)
#    2810     inner_rank=3,
#    2811     name=name)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\gen_nn_ops.py:1345, in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1343   pass
#    1344 try:
# -> 1345   return conv2d_eager_fallback(
#    1346       input, filter, strides=strides, use_cudnn_on_gpu=use_cudnn_on_gpu,
#    1347       padding=padding, explicit_paddings=explicit_paddings,
#    1348       data_format=data_format, dilations=dilations, name=name, ctx=_ctx)
#    1349 except _core._SymbolicException:
#    1350   pass  # Add nodes to the TensorFlow graph.
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\gen_nn_ops.py:1434, in conv2d_eager_fallback(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name, ctx)
#    1430 _inputs_flat = [input, filter]
#    1431 _attrs = ("T", _attr_T, "strides", strides, "use_cudnn_on_gpu",
#    1432 use_cudnn_on_gpu, "padding", padding, "explicit_paddings",
#    1433 explicit_paddings, "data_format", data_format, "dilations", dilations)
# -> 1434 _result = _execute.execute(b"Conv2D", 1, inputs=_inputs_flat, attrs=_attrs,
#    1435                            ctx=ctx, name=name)
#    1436 if _execute.must_record_gradient():
#    1437   _execute.record_gradient(
#    1438       "Conv2D", _inputs_flat, _attrs, _result)
#
# File c:\Users\P3mas\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # 3 Pre-treatment of annotations

# %%
# Find the maximum length
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# Choose the 5000 most frequent words from the vocabulary
top_k = 5000
# The Tokenizer class allows text preprocessing for neural networks
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
# Build a vocabulary based on the train_captions list
tokenizer.fit_on_texts(train_captions)

# Create the token used to pad the annotations to equalize their length
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# Create vectors (lists of integer tokens) from annotations (list of words)
train_seqs = tokenizer.texts_to_sequences(train_captions)

# Pad each vector up to the maximum annotation length
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# Calculate the maximum length, which will be used to store attention weights
# It will be useful later for display during evaluation
max_length = calc_max_length(train_seqs)

# Convert the tokenizer to a JSON string
tokenizer_json = tokenizer.to_json()

# Save the JSON string to a file
with open('tokenizer.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_json, ensure_ascii=False))

# %% [markdown]
# # 1 Creating training & testing datasets

# %%
img_to_cap_vector = collections.defaultdict(list)
# Create a dictionary mapping image paths (with .npy files) to annotations
# Images are duplicated because there are multiple annotations per image
print(len(img_name_vector), len(cap_vector))
for img, cap in zip(img_name_vector, cap_vector):
    img_to_cap_vector[img].append(cap)

"""
Create training and validation datasets using 
a random 80-20 split
"""
# Take the keys (names of processed image files), *these won't be duplicated*
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)  # Shuffle the keys
# Split the indices into training and test
slice_index = int(len(img_keys) * 0.8)
# Divide into train and validation
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

"""
The training and test sets are in the form of
lists containing mappings: (preprocessed image ---> annotation tokens (words))
"""

# Loop to build the training set
img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
    capt_len = len(img_to_cap_vector[imgt])
    # Duplicate images by the number of annotations per image
    img_name_train.extend([imgt] * capt_len)
    cap_train.extend(img_to_cap_vector[imgt])

# Loop to build the test set
img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
    capv_len = len(img_to_cap_vector[imgv])
    # Duplicate images by the number of annotations per image
    img_name_val.extend([imgv] * capv_len)
    cap_val.extend(img_to_cap_vector[imgv])

len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# 50027 50027
# (40023, 40023, 10004, 10004)

# %%
# Feel free to modify these parameters based on your machine
BATCH_SIZE = 64  # batch size
BUFFER_SIZE = 1000  # buffer size for shuffling data
embedding_dim = 256
units = 512  # Size of the hidden layer in the RNN
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE

# The shape of the vector extracted from InceptionV3 is (64, 2048)
# The following two variables represent the shape of this vector
features_shape = 2048
attention_features_shape = 64

# Function to load numpy files of preprocessed images
def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8') + '.npy')
    return img_tensor, cap

# Create a dataset of "Tensors" (used to represent large datasets)
# The dataset is created from "img_name_train" and "cap_train"
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Using map to load the numpy files (possibly in parallel)
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
    map_func, [item1, item2], [tf.float32, tf.int32]),
    num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Shuffle the data and split into batches
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %% [markdown]
# # 2 Models architecture

# %%
class CNN_Encoder(tf.keras.Model):
    # Since the images are already preprocessed by InceptionV3 and represented in compact form,
    # the CNN encoder will simply pass these features through a dense layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, features, hidden):
        # features (CNN_encoder output) shape == (batch_size, 64, embedding_dim)

        # shape of the hidden layer == (batch_size, hidden_size)
        hidden_with_time_axis = tf.expand_dims(hidden, 1)

        attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                             self.W2(hidden_with_time_axis)))

        # This gives you an unnormalized score for each image feature.
        score = self.V(attention_hidden_layer)

        attention_weights = tf.nn.softmax(score, axis=1)

        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
class RNN_Decoder(tf.keras.Model):
    def __init__(self, embedding_dim, units, vocab_size):
        super(RNN_Decoder, self).__init__()
        self.units = units

        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        # Dense layer that will take the GRU output as input
        self.fc1 = tf.keras.layers.Dense(self.units)
        # Final dense layer
        self.fc2 = tf.keras.layers.Dense(vocab_size)

        self.attention = BahdanauAttention(self.units)

    def call(self, x, features, hidden):
        # Attention is defined by a separate model
        context_vector, attention_weights = self.attention(features, hidden)
        # Pass the current word to the embedding layer
        x = self.embedding(x)
        # Concatenation
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        # Pass the concatenated vector to the GRU
        output, state = self.gru(x)

        # Dense layer
        y = self.fc1(output)

        y = tf.reshape(y, (-1, x.shape[2]))

        # Dense layer
        y = self.fc2(y)

        return y, state, attention_weights

    def reset_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %% [markdown]
# **Combining encoding & decoding**

# %%
# Create the encoder
encoder = CNN_Encoder(embedding_dim)
# Create the decoder
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
# ADAM optimizer
optimizer = tf.keras.optimizers.Adam()
# Loss function
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %% [markdown]
# # To keep track of our training and save it, we will use the class [`tf.train.Checkpoint`](https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint).

# %%
checkpoint_path = os.path.abspath("checkpoints")
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %% [markdown]
# # Initialize the starting epoch for training in `start_epoch`.
# # The `tf.train.Checkpoint` class allows you to resume training where you left off if it was previously interrupted.

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
    # Restore the latest checkpoint from checkpoint_path
    ckpt.restore(ckpt_manager.latest_checkpoint)

# %% [markdown]
# # 3 Training & testing :
# # 3.1 Training

# %%
loss_plot = []

@tf.function
def train_step(img_tensor, target):
    loss = 0

    # Initialize hidden state for each batch
    hidden = decoder.reset_state(batch_size=target.shape[0])

    # Initialize the decoder input
    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

    with tf.GradientTape() as tape:  # Allows gradient computation for the loss
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            # Predict the i-th word of the batch with the decoder
            predictions, hidden, _ = decoder(dec_input, features, hidden)
            loss += loss_function(target[:, i], predictions)

            # The correct word at step i is given as input to step (i+1)
            dec_input = tf.expand_dims(target[:, i], 1)

    total_loss = (loss / int(target.shape[1]))

    trainable_variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, trainable_variables)

    optimizer.apply_gradients(zip(gradients, trainable_variables))

    return loss, total_loss

# %% [markdown]
# # The overall code containing the training loop is shown below.
# # This loop goes through the training dataset batch by batch and trains the network with them.

# %%
EPOCHS = 40

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            print('Epoch {} Batch {} Loss {:.4f}'.format(
                epoch + 1, batch, batch_loss.numpy() / int(target.shape[1])))

    # Save the loss
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
        ckpt_manager.save()

    print('Epoch {} Loss {:.6f}'.format(epoch + 1,
                                        total_loss / num_steps))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))

# Display the training loss curve
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()
# Out:
# 2023-10-26 06:57:59.738079: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# 2023-10-26 06:57:59.956940: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# 2023-10-26 06:58:41.748550: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8efc3bc370 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-26 06:58:41.748592: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro P4000, Compute Capability 6.1
# 2023-10-26 06:58:41.761381: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-26 06:58:41.893941: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1 Batch 0 Loss 1.9846
# 2023-10-26 06:58:43.842021: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# 2023-10-26 06:58:44.131230: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# 2023-10-26 06:58:44.371092: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# Epoch 1 Batch 100 Loss 1.1641
# Epoch 1 Batch 200 Loss 0.9708
# Epoch 1 Batch 300 Loss 0.8889
# Epoch 1 Batch 400 Loss 0.8443
# Epoch 1 Batch 500 Loss 0.8598
# Epoch 1 Batch 600 Loss 0.8547
# Epoch 1 Loss 0.986356
# Time taken for 1 epoch 213.20720648765564 sec
# Epoch 2 Batch 0 Loss 0.8348
# Epoch 2 Batch 100 Loss 0.7404
# Epoch 2 Batch 200 Loss 0.7315
# Epoch 2 Batch 300 Loss 0.7035
# Epoch 2 Batch 400 Loss 0.7142
# Epoch 2 Batch 500 Loss 0.7098
# Epoch 2 Batch 600 Loss 0.7103
# Epoch 2 Loss 0.764015
# Time taken for 1 epoch 140.93625354766846 sec
# Epoch 3 Batch 0 Loss 0.7169
# Epoch 3 Batch 100 Loss 0.7008
# Epoch 3 Batch 200 Loss 0.6765
# Epoch 3 Batch 300 Loss 0.6460
# Epoch 3 Batch 400 Loss 0.7128
# Epoch 3 Batch 500 Loss 0.6833
# Epoch 3 Batch 600 Loss 0.6325
# Epoch 3 Loss 0.698214
# Time taken for 1 epoch 141.25379848480225 sec
# Epoch 4 Batch 0 Loss 0.7074
# Epoch 4 Batch 100 Loss 0.6409
# Epoch 4 Batch 200 Loss 0.6305
# Epoch 4 Batch 300 Loss 0.6771
# Epoch 4 Batch 400 Loss 0.6464
# Epoch 4 Batch 500 Loss 0.5726
# Epoch 4 Batch 600 Loss 0.6001
# Epoch 4 Loss 0.654152
# Time taken for 1 epoch 142.94302797317505 sec
# Epoch 5 Batch 0 Loss 0.7380
# Epoch 5 Batch 100 Loss 0.7150
# Epoch 5 Batch 200 Loss 0.6288
# Epoch 5 Batch 300 Loss 0.5720
# Epoch 5 Batch 400 Loss 0.5631
# Epoch 5 Batch 500 Loss 0.6299
# Epoch 5 Batch 600 Loss 0.5900
# Epoch 5 Loss 0.618724
# Time taken for 1 epoch 144.0438950061798 sec
# Epoch 6 Batch 0 Loss 0.6008
# Epoch 6 Batch 100 Loss 0.6038
# Epoch 6 Batch 200 Loss 0.5872
# Epoch 6 Batch 300 Loss 0.5810
# Epoch 6 Batch 400 Loss 0.5745
# Epoch 6 Batch 500 Loss 0.6600
# Epoch 6 Batch 600 Loss 0.5505
# Epoch 6 Loss 0.587067
# Time taken for 1 epoch 145.15972352027893 sec
# Epoch 7 Batch 0 Loss 0.6004
# Epoch 7 Batch 100 Loss 0.4962
# Epoch 7 Batch 200 Loss 0.5368
# Epoch 7 Batch 300 Loss 0.5682
# Epoch 7 Batch 400 Loss 0.5763
# Epoch 7 Batch 500 Loss 0.6194
# Epoch 7 Batch 600 Loss 0.5408
# Epoch 7 Loss 0.558542
# Time taken for 1 epoch 143.7396867275238 sec
# Epoch 8 Batch 0 Loss 0.5515
# Epoch 8 Batch 100 Loss 0.5242
# Epoch 8 Batch 200 Loss 0.4417
# Epoch 8 Batch 300 Loss 0.5581
# Epoch 8 Batch 400 Loss 0.5308
# Epoch 8 Batch 500 Loss 0.5455
# Epoch 8 Batch 600 Loss 0.5248
# Epoch 8 Loss 0.533030
# Time taken for 1 epoch 144.251398563385 sec
# Epoch 9 Batch 0 Loss 0.5551
# Epoch 9 Batch 100 Loss 0.5075
# Epoch 9 Batch 200 Loss 0.4456
# Epoch 9 Batch 300 Loss 0.4231
# Epoch 9 Batch 400 Loss 0.4366
# Epoch 9 Batch 500 Loss 0.5174
# Epoch 9 Batch 600 Loss 0.4866
# Epoch 9 Loss 0.507458
# Time taken for 1 epoch 144.26390027999878 sec
# Epoch 10 Batch 0 Loss 0.5141
# Epoch 10 Batch 100 Loss 0.4752
# Epoch 10 Batch 200 Loss 0.4235
# Epoch 10 Batch 300 Loss 0.4512
# Epoch 10 Batch 400 Loss 0.4618
# Epoch 10 Batch 500 Loss 0.4650
# Epoch 10 Batch 600 Loss 0.4865
# Epoch 10 Loss 0.483313
# Time taken for 1 epoch 144.2763819694519 sec
# Epoch 11 Batch 0 Loss 0.4589
# Epoch 11 Batch 100 Loss 0.4401
# Epoch 11 Batch 200 Loss 0.4800
# Epoch 11 Batch 300 Loss 0.5017
# Epoch 11 Batch 400 Loss 0.4754
# Epoch 11 Batch 500 Loss 0.4825
# Epoch 11 Batch 600 Loss 0.4627
# Epoch 11 Loss 0.461092
# Time taken for 1 epoch 144.56427121162415 sec
# Epoch 12 Batch 0 Loss 0.4675
# Epoch 12 Batch 100 Loss 0.4793
# Epoch 12 Batch 200 Loss 0.4536
# Epoch 12 Batch 300 Loss 0.4543
# Epoch 12 Batch 400 Loss 0.4228
# Epoch 12 Batch 500 Loss 0.4774
# Epoch 12 Batch 600 Loss 0.4107
# Epoch 12 Loss 0.440058
# Time taken for 1 epoch 145.3180558681488 sec
# Epoch 13 Batch 0 Loss 0.4932
# Epoch 13 Batch 100 Loss 0.4124
# Epoch 13 Batch 200 Loss 0.4133
# Epoch 13 Batch 300 Loss 0.4181
# Epoch 13 Batch 400 Loss 0.4389
# Epoch 13 Batch 500 Loss 0.4055
# Epoch 13 Batch 600 Loss 0.3898
# Epoch 13 Loss 0.421257
# Time taken for 1 epoch 144.3908839225769 sec
# Epoch 14 Batch 0 Loss 0.4887
# Epoch 14 Batch 100 Loss 0.3802
# Epoch 14 Batch 200 Loss 0.3971
# Epoch 14 Batch 300 Loss 0.4127
# Epoch 14 Batch 400 Loss 0.3995
# Epoch 14 Batch 500 Loss 0.3971
# Epoch 14 Batch 600 Loss 0.3507
# Epoch 14 Loss 0.403975
# Time taken for 1 epoch 144.27258968353271 sec
# Epoch 15 Batch 0 Loss 0.4275
# Epoch 15 Batch 100 Loss 0.3876
# Epoch 15 Batch 200 Loss 0.4441
# Epoch 15 Batch 300 Loss 0.3949
# Epoch 15 Batch 400 Loss 0.3944
# Epoch 15 Batch 500 Loss 0.3924
# Epoch 15 Batch 600 Loss 0.3795
# Epoch 15 Loss 0.385555
# Time taken for 1 epoch 144.91146039962769 sec
# Epoch 16 Batch 0 Loss 0.3747
# Epoch 16 Batch 100 Loss 0.3750
# Epoch 16 Batch 200 Loss 0.3641
# Epoch 16 Batch 300 Loss 0.3382
# Epoch 16 Batch 400 Loss 0.3864
# Epoch 16 Batch 500 Loss 0.3293
# Epoch 16 Batch 600 Loss 0.3520
# Epoch 16 Loss 0.369880
# Time taken for 1 epoch 144.37813210487366 sec
# Epoch 17 Batch 0 Loss 0.3580
# Epoch 17 Batch 100 Loss 0.3575
# Epoch 17 Batch 200 Loss 0.3523
# Epoch 17 Batch 300 Loss 0.3511
# Epoch 17 Batch 400 Loss 0.3605
# Epoch 17 Batch 500 Loss 0.3570
# Epoch 17 Batch 600 Loss 0.3277
# Epoch 17 Loss 0.355431
# Time taken for 1 epoch 144.55526852607727 sec
# Epoch 18 Batch 0 Loss 0.3929
# Epoch 18 Batch 100 Loss 0.3500
# Epoch 18 Batch 200 Loss 0.3549
# Epoch 18 Batch 300 Loss 0.3374
# Epoch 18 Batch 400 Loss 0.3475
# Epoch 18 Batch 500 Loss 0.3276
# Epoch 18 Batch 600 Loss 0.3247
# Epoch 18 Loss 0.341837
# Time taken for 1 epoch 144.68726134300232 sec
# Epoch 19 Batch 0 Loss 0.3731
# Epoch 19 Batch 100 Loss 0.3144
# Epoch 19 Batch 200 Loss 0.3294
# Epoch 19 Batch 300 Loss 0.3594
# Epoch 19 Batch 400 Loss 0.3540
# Epoch 19 Batch 500 Loss 0.3056
# Epoch 19 Batch 600 Loss 0.3022
# Epoch 19 Loss 0.328785
# Time taken for 1 epoch 143.71677541732788 sec
# Epoch 20 Batch 0 Loss 0.3592
# Epoch 20 Batch 100 Loss 0.3004
# Epoch 20 Batch 200 Loss 0.3182
# Epoch 20 Batch 300 Loss 0.3356
# Epoch 20 Batch 400 Loss 0.3222
# Epoch 20 Batch 500 Loss 0.3115
# Epoch 20 Batch 600 Loss 0.3068
# Epoch 20 Loss 0.317362
# Time taken for 1 epoch 143.82218956947327 sec
# Epoch 21 Batch 0 Loss 0.3350
# Epoch 21 Batch 100 Loss 0.2953
# Epoch 21 Batch 200 Loss 0.2798
# Epoch 21 Batch 300 Loss 0.3048
# Epoch 21 Batch 400 Loss 0.2879
# Epoch 21 Batch 500 Loss 0.3063
# Epoch 21 Batch 600 Loss 0.2868
# Epoch 21 Loss 0.306461
# Time taken for 1 epoch 144.53014135360718 sec
# Epoch 22 Batch 0 Loss 0.3267
# Epoch 22 Batch 100 Loss 0.2996
# Epoch 22 Batch 200 Loss 0.2840
# Epoch 22 Batch 300 Loss 0.3110
# Epoch 22 Batch 400 Loss 0.2972
# Epoch 22 Batch 500 Loss 0.2951
# Epoch 22 Batch 600 Loss 0.2848
# Epoch 22 Loss 0.296629
# Time taken for 1 epoch 143.74722027778625 sec
# Epoch 23 Batch 0 Loss 0.3159
# Epoch 23 Batch 100 Loss 0.2997
# Epoch 23 Batch 200 Loss 0.3054
# Epoch 23 Batch 300 Loss 0.2927
# Epoch 23 Batch 400 Loss 0.2917
# Epoch 23 Batch 500 Loss 0.2931
# Epoch 23 Batch 600 Loss 0.2696
# Epoch 23 Loss 0.288085
# Time taken for 1 epoch 144.41752243041992 sec
# Epoch 24 Batch 0 Loss 0.2969
# Epoch 24 Batch 100 Loss 0.2782
# Epoch 24 Batch 200 Loss 0.2920
# Epoch 24 Batch 300 Loss 0.2831
# Epoch 24 Batch 400 Loss 0.2801
# Epoch 24 Batch 500 Loss 0.2834
# Epoch 24 Batch 600 Loss 0.2790
# Epoch 24 Loss 0.279017
# Time taken for 1 epoch 144.22831869125366 sec
# Epoch 25 Batch 0 Loss 0.2986
# Epoch 25 Batch 100 Loss 0.2530
# Epoch 25 Batch 200 Loss 0.2658
# Epoch 25 Batch 300 Loss 0.2654
# Epoch 25 Batch 400 Loss 0.2821
# Epoch 25 Batch 500 Loss 0.2630
# Epoch 25 Batch 600 Loss 0.2647
# Epoch 25 Loss 0.269930
# Time taken for 1 epoch 144.53856110572815 sec
# Epoch 26 Batch 0 Loss 0.2646
# Epoch 26 Batch 100 Loss 0.2700
# Epoch 26 Batch 200 Loss 0.2942
# Epoch 26 Batch 300 Loss 0.2630
# Epoch 26 Batch 400 Loss 0.2847
# Epoch 26 Batch 500 Loss 0.2701
# Epoch 26 Batch 600 Loss 0.2650
# Epoch 26 Loss 0.262559
# Time taken for 1 epoch 145.18477749824524 sec
# Epoch 27 Batch 0 Loss 0.2956
# Epoch 27 Batch 100 Loss 0.2702
# Epoch 27 Batch 200 Loss 0.2624
# Epoch 27 Batch 300 Loss 0.2520
# Epoch 27 Batch 400 Loss 0.2513
# Epoch 27 Batch 500 Loss 0.2408
# Epoch 27 Batch 600 Loss 0.2283
# Epoch 27 Loss 0.255895
# Time taken for 1 epoch 144.6415741443634 sec
# Epoch 28 Batch 0 Loss 0.2767
# Epoch 28 Batch 100 Loss 0.2504
# Epoch 28 Batch 200 Loss 0.2363
# Epoch 28 Batch 300 Loss 0.2407
# Epoch 28 Batch 400 Loss 0.2651
# Epoch 28 Batch 500 Loss 0.2435
# Epoch 28 Batch 600 Loss 0.2550
# Epoch 28 Loss 0.249480
# Time taken for 1 epoch 144.57233333587646 sec
# Epoch 29 Batch 0 Loss 0.2596
# Epoch 29 Batch 100 Loss 0.2518
# Epoch 29 Batch 200 Loss 0.2646
# Epoch 29 Batch 300 Loss 0.2554
# Epoch 29 Batch 400 Loss 0.2354
# Epoch 29 Batch 500 Loss 0.2533
# Epoch 29 Batch 600 Loss 0.2259
# Epoch 29 Loss 0.246026
# Time taken for 1 epoch 144.28638243675232 sec
# Epoch 30 Batch 0 Loss 0.2616
# Epoch 30 Batch 100 Loss 0.2445
# Epoch 30 Batch 200 Loss 0.2590
# Epoch 30 Batch 300 Loss 0.2115
# Epoch 30 Batch 400 Loss 0.2410
# Epoch 30 Batch 500 Loss 0.2493
# Epoch 30 Batch 600 Loss 0.2105
# Epoch 30 Loss 0.238593
# Time taken for 1 epoch 144.43601059913635 sec
# Epoch 31 Batch 0 Loss 0.2233
# Epoch 31 Batch 100 Loss 0.2403
# Epoch 31 Batch 200 Loss 0.2236
# Epoch 31 Batch 300 Loss 0.2191
# Epoch 31 Batch 400 Loss 0.2364
# Epoch 31 Batch 500 Loss 0.2614
# Epoch 31 Batch 600 Loss 0.2318
# Epoch 31 Loss 0.236270
# Time taken for 1 epoch 145.24247074127197 sec
# Epoch 32 Batch 0 Loss 0.2284
# Epoch 32 Batch 100 Loss 0.2468
# Epoch 32 Batch 200 Loss 0.2103
# Epoch 32 Batch 300 Loss 0.2184
# Epoch 32 Batch 400 Loss 0.2303
# Epoch 32 Batch 500 Loss 0.2391
# Epoch 32 Batch 600 Loss 0.2182
# Epoch 32 Loss 0.229020
# Time taken for 1 epoch 144.8929204940796 sec
# Epoch 33 Batch 0 Loss 0.2509
# Epoch 33 Batch 100 Loss 0.2219
# Epoch 33 Batch 200 Loss 0.2331
# Epoch 33 Batch 300 Loss 0.2338
# Epoch 33 Batch 400 Loss 0.2346
# Epoch 33 Batch 500 Loss 0.2169
# Epoch 33 Batch 600 Loss 0.2027
# Epoch 33 Loss 0.223883
# Time taken for 1 epoch 144.82721829414368 sec
# Epoch 34 Batch 0 Loss 0.2460
# Epoch 34 Batch 100 Loss 0.2134
# Epoch 34 Batch 200 Loss 0.2119
# Epoch 34 Batch 300 Loss 0.2205
# Epoch 34 Batch 400 Loss 0.2188
# Epoch 34 Batch 500 Loss 0.2196
# Epoch 34 Batch 600 Loss 0.2171
# Epoch 34 Loss 0.219126
# Time taken for 1 epoch 144.7557566165924 sec
# Epoch 35 Batch 0 Loss 0.2110
# Epoch 35 Batch 100 Loss 0.1975
# Epoch 35 Batch 200 Loss 0.2079
# Epoch 35 Batch 300 Loss 0.2183
# Epoch 35 Batch 400 Loss 0.2264
# Epoch 35 Batch 500 Loss 0.2235
# Epoch 35 Batch 600 Loss 0.1935
# Epoch 35 Loss 0.216950
# Time taken for 1 epoch 144.92365384101868 sec
# Epoch 36 Batch 0 Loss 0.2509
# Epoch 36 Batch 100 Loss 0.2180
# Epoch 36 Batch 200 Loss 0.2233
# Epoch 36 Batch 300 Loss 0.2254
# Epoch 36 Batch 400 Loss 0.2228
# Epoch 36 Batch 500 Loss 0.2096
# Epoch 36 Batch 600 Loss 0.1796
# Epoch 36 Loss 0.211816
# Time taken for 1 epoch 202.10291957855225 sec
# Epoch 37 Batch 0 Loss 0.2139
# Epoch 37 Batch 100 Loss 0.1822
# Epoch 37 Batch 200 Loss 0.2248
# Epoch 37 Batch 300 Loss 0.1981
# Epoch 37 Batch 400 Loss 0.2281
# Epoch 37 Batch 500 Loss 0.2167
# Epoch 37 Batch 600 Loss 0.2102
# Epoch 37 Loss 0.208293
# Time taken for 1 epoch 140.94409203529358 sec
# Epoch 38 Batch 0 Loss 0.2169
# Epoch 38 Batch 100 Loss 0.2021
# Epoch 38 Batch 200 Loss 0.1952
# Epoch 38 Batch 300 Loss 0.2089
# Epoch 38 Batch 400 Loss 0.1985
# Epoch 38 Batch 500 Loss 0.1898
# Epoch 38 Batch 600 Loss 0.2140
# Epoch 38 Loss 0.205030
# Time taken for 1 epoch 144.03934121131897 sec
# Epoch 39 Batch 0 Loss 0.2203
# Epoch 39 Batch 100 Loss 0.1953
# Epoch 39 Batch 200 Loss 0.1928
# Epoch 39 Batch 300 Loss 0.2188
# Epoch 39 Batch 400 Loss 0.2459
# Epoch 39 Batch 500 Loss 0.2143
# Epoch 39 Batch 600 Loss 0.1903
# Epoch 39 Loss 0.201659
# Time taken for 1 epoch 145.38685607910156 sec
# Epoch 40 Batch 0 Loss 0.2692
# Epoch 40 Batch 100 Loss 0.1844
# Epoch 40 Batch 200 Loss 0.2149
# Epoch 40 Batch 300 Loss 0.1949
# Epoch 40 Batch 400 Loss 0.1993
# Epoch 40 Batch 500 Loss 0.1802
# Epoch 40 Batch 600 Loss 0.1936
# Epoch 40 Loss 0.197989
# Time taken for 1 epoch 144.71552872657776 sec

# %% [markdown]
# # 3.2 Test

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# Function to visualize attention on the image
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for l in range(len_result):
        temp_att = np.resize(attention_plot[l], (8, 8))
        ax = fig.add_subplot(len_result//2, len_result//2, l+1)
        ax.set_title(result[l])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Display of some examples using the result returned by the evaluation.

# %%
# Display a few annotations from the test set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
print(rid)
print(len(cap_val))
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Predicted Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# 1762
# 10004
# Real Caption: <start> a pastry with candles made to look like an animal <end>
# Prediction Caption: a decorations with an art decorated like a teddy bear <end>

# %%
Image.open(img_name_val[rid])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x458>
